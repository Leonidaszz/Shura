# %%
# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !apt -y install -qq aria2
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !pip install -q xformers==0.0.16 triton==2.0.0 -U

# !git clone https://github.com/Leonidaszz/Shura /content/Excalibur
# !python /content/Excalibur/Excalibur.py

# %cd /content/Shura

#Instal-Controlnet
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_canny-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_canny-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_depth-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_depth-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_hed-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_hed-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_mlsd-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_mlsd-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_normal-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_normal-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_openpose-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_openpose-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_scribble-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_scribble-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_seg-fp16.safetensors -d /content/Shura/extensions/sd-webui-controlnet/models -o control_seg-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth -d /content/Shura/extensions/sd-webui-controlnet/annotator/openpose -o hand_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth -d /content/Shura/extensions/sd-webui-controlnet/annotator/openpose -o body_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt -d /content/Shura/extensions/sd-webui-controlnet/annotator/midas -o dpt_hybrid-midas-501f0c75.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth -d /content/Shura/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_large_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth -d /content/Shura/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_tiny_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth -d /content/Shura/extensions/sd-webui-controlnet/annotator/hed -o network-bsds500.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth -d /content/Shura/extensions/sd-webui-controlnet/annotator/uniformer -o upernet_global_small.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_style_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_color_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/Shura/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd14v1.pth

#Instal-Checkpoint
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3.safetensors -d /content/Shura/models/Stable-diffusion -o AOM3.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A1.safetensors -d /content/Shura/models/Stable-diffusion -o AOM3A1.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A2.safetensors -d /content/Shura/models/Stable-diffusion -o AOM3A2.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A3.safetensors -d /content/Shura/models/Stable-diffusion -o AOM3A3.safetensors

#Instal-vae
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /content/Shura/models/Stable-diffusion -o orangemix.vae.pt

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/Shura/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/Shura/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/Shura/modules/shared.py

# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple
# Out:
# /content
# env: TF_CPP_MIN_LOG_LEVEL=1
# 30 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2023-04-23 10:40:21--  http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203696 (199K) [application/x-debian-package]
# Saving to: ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’
#
# libgoogle-perftools 100%[===================>] 198.92K   451KB/s    in 0.4s
#
# 2023-04-23 10:40:21 (451 KB/s) - ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’ saved [203696/203696]
#
# --2023-04-23 10:40:21--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.222, 185.125.189.223, 2620:2d:4000:1001::8003, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.222|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274642/google-perftools_2.5-2.2ubuntu3_all.deb [following]
# --2023-04-23 10:40:22--  https://launchpadlibrarian.net/367274642/google-perftools_2.5-2.2ubuntu3_all.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294224 (287K) [application/x-debian-package]
# Saving to: ‘google-perftools_2.5-2.2ubuntu3_all.deb’
#
# google-perftools_2. 100%[===================>] 287.33K   588KB/s    in 0.5s
#
# 2023-04-23 10:40:23 (588 KB/s) - ‘google-perftools_2.5-2.2ubuntu3_all.deb’ saved [294224/294224]
#
# --2023-04-23 10:40:23--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.222, 185.125.189.223, 2620:2d:4000:1001::8003, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.222|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274648/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb [following]
# --2023-04-23 10:40:24--  https://launchpadlibrarian.net/367274648/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91644 (89K) [application/x-debian-package]
# Saving to: ‘libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb’
#
# libtcmalloc-minimal 100%[===================>]  89.50K   368KB/s    in 0.2s
#
# 2023-04-23 10:40:24 (368 KB/s) - ‘libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb’ saved [91644/91644]
#
# --2023-04-23 10:40:24--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpad.net (launchpad.net)... 185.125.189.222, 185.125.189.223, 2620:2d:4000:1001::8003, ...
# Connecting to launchpad.net (launchpad.net)|185.125.189.222|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://launchpadlibrarian.net/367274647/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb [following]
# --2023-04-23 10:40:25--  https://launchpadlibrarian.net/367274647/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 189628 (185K) [application/x-debian-package]
# Saving to: ‘libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb’
#
# libgoogle-perftools 100%[===================>] 185.18K   458KB/s    in 0.4s
#
# 2023-04-23 10:40:26 (458 KB/s) - ‘libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb’ saved [189628/189628]
#
# The following NEW packages will be installed:
#   libunwind-dev
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 472 kB of archives.
# After this operation, 4,164 kB of additional disk space will be used.
# Selecting previously unselected package libunwind-dev:amd64.
# (Reading database ... 122352 files and directories currently installed.)
# Preparing to unpack .../libunwind-dev_1.2.1-9ubuntu0.1_amd64.deb ...
# Unpacking libunwind-dev:amd64 (1.2.1-9ubuntu0.1) ...
# Setting up libunwind-dev:amd64 (1.2.1-9ubuntu0.1) ...
# Processing triggers for man-db (2.9.1-1) ...
# dpkg: warning: downgrading google-perftools from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# (Reading database ... 122405 files and directories currently installed.)
# Preparing to unpack google-perftools_2.5-2.2ubuntu3_all.deb ...
# Unpacking google-perftools (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# dpkg: warning: downgrading libgoogle-perftools4:amd64 from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# Preparing to unpack libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools4 (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# Selecting previously unselected package libgoogle-perftools-dev.
# Preparing to unpack libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# dpkg: warning: downgrading libtcmalloc-minimal4:amd64 from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# Preparing to unpack libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4 (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# Setting up libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# Setting up google-perftools (2.5-2.2ubuntu3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# env: LD_PRELOAD=libtcmalloc.so
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 34 not upgraded.
# Need to get 1,475 kB of archives.
# After this operation, 5,959 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 122496 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# Unpacking aria2 (1.35.0-1build1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.2) ...
# Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# Setting up aria2 (1.35.0-1build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 50.8 MB/s eta 0:00:01tcmalloc: large alloc 1977925632 bytes == 0x3306000 @  0x7fa7065291e7 0x6e6e9e 0x629594 0x685a9c 0x564b38 0x564bcf 0x53f72a 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c1d3 0x62c60f 0x5ab826 0x62c994 0x5ac335 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x548478 0x537b6a 0x6a2ad6
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 2.0/2.0 GB 57.1 MB/s eta 0:00:01tcmalloc: large alloc 2472411136 bytes == 0x79152000 @  0x7fa70652a615 0x629504 0x685a9c 0x564b38 0x564bcf 0x53f72a 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c1d3 0x62c60f 0x5ab826 0x62c994 0x5ac335 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x548478 0x537b6a 0x6a2ad6 0x5afd01
# tcmalloc: large alloc 1977925632 bytes == 0x3306000 @  0x7fa7065291e7 0x62e9b6 0x630070 0x53f72a 0x5ab826 0x62c994 0x5ab826 0x62c994 0x5ab826 0x62c994 0x548478 0x537b6a 0x6a2ad6 0x5afd01 0x62c1d3 0x5482c4 0x5afd01 0x5a9eb4 0x5483e1 0x5afd01 0x62c1d3 0x62c60f 0x5ab826 0x5a9eb4 0x5483e1 0x5ac335 0x53d523 0x5abacc 0x53d523 0x5abacc 0x53d523
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 763.2 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 52.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 69.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 73.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 MB 15.3 MB/s eta 0:00:00
# Cloning into '/content/Excalibur'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 25 (delta 9), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (25/25), 14.81 KiB | 2.12 MiB/s, done.
# Cloning into '/content/Shura'...
# remote: Enumerating objects: 17762, done.
# remote: Total 17762 (delta 0), reused 0 (delta 0), pack-reused 17762
# Receiving objects: 100% (17762/17762), 28.28 MiB | 29.26 MiB/s, done.
# Resolving deltas: 100% (12405/12405), done.
# Cloning into '/content/Shura/embeddings/negative'...
# remote: Enumerating objects: 12, done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 12
# Unpacking objects: 100% (12/12), 1.70 KiB | 868.00 KiB/s, done.
# Cloning into '/content/Shura/models/Lora/positive'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 6
# Unpacking objects: 100% (9/9), 1.28 KiB | 1.28 MiB/s, done.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 16ef71|OK  |   156MiB/s|/content/Shura/models/ESRGAN/4x-UltraSharp.pth
#
# Status Legend:
# (OK):download completed.
# --2023-04-23 10:43:17--  https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 533 [text/plain]
# Saving to: ‘/content/Shura/scripts/run_n_times.py’
#
# /content/Shura/scri 100%[===================>]     533  --.-KB/s    in 0s
#
# 2023-04-23 10:43:17 (41.5 MB/s) - ‘/content/Shura/scripts/run_n_times.py’ saved [533/533]
#
# Cloning into '/content/Shura/extensions/deforum-for-automatic1111-webui'...
# remote: Enumerating objects: 11627, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 11627 (delta 59), reused 91 (delta 50), pack-reused 11517
# Receiving objects: 100% (11627/11627), 127.51 MiB | 27.60 MiB/s, done.
# Resolving deltas: 100% (7018/7018), done.
# Cloning into '/content/Shura/extensions/stable-diffusion-webui-images-browser'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 172 (delta 32), reused 32 (delta 23), pack-reused 116
# Receiving objects: 100% (172/172), 65.54 KiB | 2.73 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# Cloning into '/content/Shura/extensions/stable-diffusion-webui-huggingface'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 121 (delta 12), reused 10 (delta 10), pack-reused 106
# Receiving objects: 100% (121/121), 28.80 KiB | 951.00 KiB/s, done.
# Resolving deltas: 100% (42/42), done.
# Cloning into '/content/Shura/extensions/sd-model-downloader'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 138 (delta 33), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (138/138), 31.57 KiB | 1.43 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# Cloning into '/content/Shura/extensions/sd-civitai-browser'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 163 (delta 37), reused 27 (delta 22), pack-reused 108
# Receiving objects: 100% (163/163), 39.16 KiB | 1.86 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# Cloning into '/content/Shura/extensions/sd-webui-additional-networks'...
# remote: Enumerating objects: 675, done.
# remote: Counting objects: 100% (291/291), done.
# remote: Compressing objects: 100% (126/126), done.
# remote: Total 675 (delta 197), reused 195 (delta 162), pack-reused 384
# Receiving objects: 100% (675/675), 202.23 KiB | 2.73 MiB/s, done.
# Resolving deltas: 100% (357/357), done.
# Cloning into '/content/Shura/extensions/sd-webui-controlnet'...
# remote: Enumerating objects: 5201, done.
# remote: Counting objects: 100% (1490/1490), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 5201 (delta 1359), reused 1327 (delta 1297), pack-reused 3711
# Receiving objects: 100% (5201/5201), 13.12 MiB | 25.35 MiB/s, done.
# Resolving deltas: 100% (2718/2718), done.
# Cloning into '/content/Shura/extensions/openpose-editor'...
# remote: Enumerating objects: 361, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 361 (delta 75), reused 67 (delta 61), pack-reused 265
# Receiving objects: 100% (361/361), 300.98 KiB | 3.76 MiB/s, done.
# Resolving deltas: 100% (153/153), done.
# Cloning into '/content/Shura/extensions/sd-webui-depth-lib'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 98 (delta 19), reused 77 (delta 9), pack-reused 0
# Unpacking objects: 100% (98/98), 5.76 MiB | 10.28 MiB/s, done.
# Cloning into '/content/Shura/extensions/tag-autocomplete'...
# remote: Enumerating objects: 1091, done.
# remote: Counting objects: 100% (1091/1091), done.
# remote: Compressing objects: 100% (430/430), done.
# remote: Total 1091 (delta 607), reused 1046 (delta 600), pack-reused 0
# Receiving objects: 100% (1091/1091), 3.81 MiB | 15.35 MiB/s, done.
# Resolving deltas: 100% (607/607), done.
# Cloning into '/content/Shura/extensions/posex'...
# remote: Enumerating objects: 402, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 402 (delta 19), reused 29 (delta 16), pack-reused 364
# Receiving objects: 100% (402/402), 11.39 MiB | 32.32 MiB/s, done.
# Resolving deltas: 100% (194/194), done.
# Cloning into '/content/Shura/extensions/tomesd'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 89 (delta 47), reused 60 (delta 26), pack-reused 0
# Unpacking objects: 100% (89/89), 1.26 MiB | 5.98 MiB/s, done.
# Cloning into '/content/Shura/extensions/sd-webui-tunnels'...
# remote: Enumerating objects: 367, done.
# remote: Counting objects: 100% (220/220), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 367 (delta 164), reused 181 (delta 128), pack-reused 147
# Receiving objects: 100% (367/367), 66.76 KiB | 2.90 MiB/s, done.
# Resolving deltas: 100% (181/181), done.
# Cloning into '/content/Shura/extensions/batchlinks-webui'...
# remote: Enumerating objects: 454, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 454 (delta 140), reused 146 (delta 94), pack-reused 248
# Receiving objects: 100% (454/454), 4.27 MiB | 19.76 MiB/s, done.
# Resolving deltas: 100% (244/244), done.
# Cloning into '/content/Shura/extensions/stable-diffusion-webui-catppuccin'...
# remote: Enumerating objects: 202, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 202 (delta 15), reused 16 (delta 8), pack-reused 172
# Receiving objects: 100% (202/202), 13.43 MiB | 29.07 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Cloning into '/content/Shura/extensions/a1111-sd-webui-locon'...
# remote: Enumerating objects: 178, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 178 (delta 11), reused 8 (delta 3), pack-reused 150
# Receiving objects: 100% (178/178), 43.42 KiB | 1.97 MiB/s, done.
# Resolving deltas: 100% (89/89), done.
# Cloning into '/content/Shura/stable-diffusion-webui-rembg'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 0), reused 9 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), 1019.03 KiB | 5.63 MiB/s, done.
# Cloning into '/content/Shura/extensions/stable-diffusion-webui-two-shot'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 176 (delta 31), reused 42 (delta 24), pack-reused 114
# Receiving objects: 100% (176/176), 22.22 MiB | 36.06 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# Cloning into '/content/Shura/extensions/sd_webui_stealth_pnginfo'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 38 (delta 14), reused 30 (delta 8), pack-reused 0
# Unpacking objects: 100% (38/38), 8.07 KiB | 1.01 MiB/s, done.
# HEAD is now at a9fed7c3 Merge pull request #8503 from mcmonkey4eva/filename-length-limit-fix
# fatal: cannot change to '/content/Shura/repositories/stable-diffusion-stability-ai': No such file or directory
# Exception: Command 'git -C /content/Shura/repositories/stable-diffusion-stability-ai reset --hard' returned non-zero exit status 128.
# /content/Shura
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7df62d|OK  |   226MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_canny-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3af64a|OK  |   212MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_depth-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d17416|OK  |   225MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_hed-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 928188|OK  |   244MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_mlsd-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9511ff|OK  |   215MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_normal-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c8336c|OK  |   218MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_openpose-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 27d5ad|OK  |   200MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_scribble-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# dfa00c|OK  |   212MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/control_seg-fp16.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 667018|OK  |   165MiB/s|/content/Shura/extensions/sd-webui-controlnet/annotator/openpose/hand_pose_model.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 91a23d|OK  |   201MiB/s|/content/Shura/extensions/sd-webui-controlnet/annotator/openpose/body_pose_model.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 44747c|OK  |   253MiB/s|/content/Shura/extensions/sd-webui-controlnet/annotator/midas/dpt_hybrid-midas-501f0c75.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4c67f8|OK  |   8.9MiB/s|/content/Shura/extensions/sd-webui-controlnet/annotator/mlsd/mlsd_large_512_fp32.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a25277|OK  |    36MiB/s|/content/Shura/extensions/sd-webui-controlnet/annotator/mlsd/mlsd_tiny_512_fp32.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fcbd80|OK  |   190MiB/s|/content/Shura/extensions/sd-webui-controlnet/annotator/hed/network-bsds500.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f56d7e|OK  |   239MiB/s|/content/Shura/extensions/sd-webui-controlnet/annotator/uniformer/upernet_global_small.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ae048a|OK  |   175MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_style_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d9eaaf|OK  |   243MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_sketch_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 73c501|OK  |   212MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_seg_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 1e1a61|OK  |   176MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_openpose_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 276230|OK  |   194MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_keypose_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a7d7d3|OK  |   191MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_depth_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ca4c10|OK  |   123MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_color_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c0a198|OK  |   196MiB/s|/content/Shura/extensions/sd-webui-controlnet/models/t2iadapter_canny_sd14v1.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c0291a|OK  |   205MiB/s|/content/Shura/models/Stable-diffusion/AOM3.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 525119|OK  |   216MiB/s|/content/Shura/models/Stable-diffusion/AOM3A1.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e33d4a|OK  |   227MiB/s|/content/Shura/models/Stable-diffusion/AOM3A2.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 281684|OK  |   215MiB/s|/content/Shura/models/Stable-diffusion/AOM3A3.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 23423d|OK  |   163MiB/s|/content/Shura/models/Stable-diffusion/orangemix.vae.pt
#
# Status Legend:
# (OK):download completed.
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: a9fed7c364061ae6efb37f797b6b522cb3cf7aa2
# Traceback (most recent call last):
#   File "/content/Shura/launch.py", line 380, in <module>
#     prepare_environment()
#   File "/content/Shura/launch.py", line 287, in prepare_environment
#     run_python("import torch; assert torch.cuda.is_available(), 'Torch is not able to use GPU; add --skip-torch-cuda-test to COMMANDLINE_ARGS variable to disable this check'")
#   File "/content/Shura/launch.py", line 137, in run_python
#     return run(f'"{python}" -c "{code}"', desc, errdesc)
#   File "/content/Shura/launch.py", line 113, in run
#     raise RuntimeError(message)
# RuntimeError: Error running command.
# Command: "/usr/bin/python3" -c "import torch; assert torch.cuda.is_available(), 'Torch is not able to use GPU; add --skip-torch-cuda-test to COMMANDLINE_ARGS variable to disable this check'"
# Error code: 1
# stdout: <empty>
# stderr: Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# AssertionError: Torch is not able to use GPU; add --skip-torch-cuda-test to COMMANDLINE_ARGS variable to disable this check
